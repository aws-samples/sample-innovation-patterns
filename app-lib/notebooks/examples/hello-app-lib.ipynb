# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys

from dotenv import find_dotenv, load_dotenv
from IPython.display import Markdown, display
from loguru import logger

load_dotenv(find_dotenv())
# Out:
# True

# %%
from app_lib.main import hello

hello()
# Out:
# hello world!
